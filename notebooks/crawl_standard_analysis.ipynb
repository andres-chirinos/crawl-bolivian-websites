# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-chirinos/crawl-bolivian-websites/blob/main/notebooks/crawl_standard_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install warcio beautifulsoup4
# Out:
# Collecting warcio
#   Downloading warcio-1.7.5-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from warcio) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Downloading warcio-1.7.5-py2.py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: warcio
# Successfully installed warcio-1.7.5

# %%
from google.colab import drive
import gzip
from warcio.archiveiterator import ArchiveIterator
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import pandas as pd
import os

# %%
def extract_outlinks(warc_file):
    outlinks = []

    # Abrir WARC (gz o normal)
    open_func = gzip.open if warc_file.endswith(".gz") else open
    with open_func(warc_file, "rb") as stream:
        for record in ArchiveIterator(stream):
            if record.rec_type == "response":
                url = record.rec_headers.get_header("WARC-Target-URI")
                payload = record.content_stream().read()

                try:
                    soup = BeautifulSoup(payload, "html.parser")
                    for tag in soup.find_all(["a", "link", "script", "img", "iframe"]):
                        href = tag.get("href") or tag.get("src")
                        alt = tag.get("alt") or tag.gettext()
                        if href:
                            parsed = urlparse(href)
                            if parsed.netloc:  # Tiene dominio
                                outlinks.append((url, href, alt))
                except Exception as e:
                    pass  # algunos payloads no son HTML válido

    return outlinks

def extract_json_xhr_calls(warc_file):
    json_xhr_calls = []

    open_func = gzip.open if warc_file.endswith(".gz") else open
    with open_func(warc_file, "rb") as stream:
        for record in ArchiveIterator(stream):
            if record.rec_type == "response":
                url = record.rec_headers.get_header("WARC-Target-URI")
                content_type = record.rec_headers.get_header("Content-Type")

                if content_type and ("application/json" in content_type or "application/x-xhr-json" in content_type):
                    json_xhr_calls.append(url)

    return json_xhr_calls

# %%
# PARAMS
zip_file = """/content/drive/Shareddrives/Repositorio de Datos/Data Lake/bolivia-web-archive/gob_bo/www_gob_bo_-20250824_015305.zip"""

# %%
drive.mount('/content/drive')

file = zip_file.split("/")[-1]
file_name = file.split(".")[0]

# !unzip -q "{zip_file}" -d "/content"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
warc_dir = f"/content/{file_name}/archive"
all_outlinks = []

# Iterate through files in the specified directory
for root, _, files in os.walk(warc_dir):
    for file in files:
        if file.endswith(".warc.gz"): # Look for .warc.gz files
            warc_file = os.path.join(root, file)
            print(f"Processing: {warc_file}")
            outlinks = extract_outlinks(warc_file)
            all_outlinks.extend(outlinks)


print(f"Total outlinks extracted: {len(all_outlinks)}")
# Out:
# Processing: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311432-3.warc.gz
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Processing: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311616-1.warc.gz
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Processing: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311411-0.warc.gz
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# /tmp/ipython-input-2150299503.py:13: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(payload, "html.parser")
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Processing: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311464-2.warc.gz
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Total outlinks extracted: 4

# %%
df = pd.DataFrame(all_outlinks, headers=["url","href","alt"])

# %%
df
# Out:
#      0     1    2
# 0  url  href  alt
# 1  url  href  alt
# 2  url  href  alt
# 3  url  href  alt

# %%
from urllib.parse import urlparse

df["href"] = df["href"].str.replace("http://", "https://")
# Standardize URLs by adding a trailing slash if it's a domain or a path without one
def standardize_url(url):
    parsed_url = urlparse(url)
    if parsed_url.path and not parsed_url.path.endswith('/') and '.' not in os.path.basename(parsed_url.path):
        return url + '/'
    elif not parsed_url.path and not parsed_url.query and not parsed_url.fragment:
         return url + '/'
    return url

df["href"] = df["href"].apply(standardize_url)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2262968694.py in <cell line: 0>()
#       1 from urllib.parse import urlparse
#       2
# ----> 3 df["href"] = df["href"].str.replace("http://", "https://")
#       4 # Standardize URLs by adding a trailing slash if it's a domain or a path without one
#       5 def standardize_url(url):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: 'href'

# %%
from urllib.parse import urlparse

# Extract the domain from the outlink URL
df['outlink_domain'] = df["href"].apply(lambda x: urlparse(x).netloc)
# Out:
# outlink_domain
# www.openstreetmap.org    6227
# datos.gob.bo             3670
# agetic.gob.bo            1835
# legas.minedu.gob.bo       128
# lapaz.bo                   71
#                          ...
# www.ylb.gob.bo              1
# ssulapaz.org                1
# www.segip.gob.bo            1
# www.probolivia.gob.bo       1
# www.sepmud.gob.bo           1
# Name: count, Length: 223, dtype: int64

# %%
df["is_bo_domain"] = df["outlink_domain"].apply(lambda x: x.endswith(".bo"))

# %%
sitios = list(df[df["is_bo_domain"]==True][1].unique())
sitios
# Out:
# ['https://datos.gob.bo/',
#  'https://agetic.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite37/',
#  'https://legas.minedu.gob.bo/',
#  'https://www.gestora.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite9/',
#  'https://www.seprec.gob.bo/index.php/tramite29/',
#  'https://www.seprec.gob.bo/index.php/tramite49/',
#  'https://vortex.produccion.gob.bo/',
#  'https://www.archivos.umss.edu.bo/wp1/',
#  'https://fnse.gob.bo/index.php/programas-y-proyectos/centro-de-habilitacion-y-rehabilitacion/',
#  'https://lapaz.bo/revalidaciones-pago-de-alquiler-de-nichos-de-cuerpo-menor-temporales/',
#  'https://www.mindef.gob.bo/node/490/',
#  'https://www.senapi.gob.bo/propiedad-intelectual/derecho-de-autor/',
#  'https://usfx.bo/',
#  'https://www.mindef.gob.bo/node/486/',
#  'https://utp.minedu.gob.bo/',
#  'https://www.ribb.gob.bo/web/site/reginfo/',
#  'https://tramitesv2.agetic.gob.bo/admin/tramites/0?tipo=tramite/',
#  'https://siscon.ypfb.gob.bo/procesos29506/',
#  'https://www.seprec.gob.bo/index.php/tramite42/',
#  'https://dejurbe.senape.gob.bo/',
#  'https://cibid.senape.gob.bo/',
#  'https://cooperativa.afcoop.gob.bo/#/login',
#  'https://www.afcoop.gob.bo/guia-de-tramites-cooperativos/',
#  'https://motomendez.gob.bo/',
#  'https://siseg.cps.org.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite41/',
#  'https://sicepa.senape.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite32/',
#  'https://siscert.ipelc.gob.bo/solicitud/',
#  'https://www.senapi.gob.bo/propiedad-intelectual/propiedad-industrial/renovacion-y-modificacion-al-signo-distintivo/',
#  'https://www.seprec.gob.bo/index.php/tramite5/',
#  'https://www.seprec.gob.bo/index.php/tramite15/',
#  'https://www.adecine.gob.bo/',
#  'https://servicios.senarecom.gob.bo/nim/formM01.php?op=A',
#  'https://onsc.senamhi.gob.bo/login/',
#  'https://www.seprec.gob.bo/index.php/tramite8/',
#  'https://lapaz.bo/evaluacion-de-estudio-de-impacto-vial-duplicate-1/',
#  'https://www.seprec.gob.bo/index.php/tramite11/',
#  'https://www.seprec.gob.bo/index.php/tramite3/',
#  'https://taypi.senavex.gob.bo/',
#  'https://lapaz.bo/internacion-de-restos-o-cenizas-a-sepultura-perpetua/',
#  'https://www.senapi.gob.bo/propiedad-intelectual/propiedad-industrial/oposiciones-al-signo-distintivo/',
#  'https://www.senapi.gob.bo/propiedad-intelectual/infraciones/',
#  'https://www.seprec.gob.bo/index.php/tramite44/',
#  'https://www.aevivienda.gob.bo/website/',
#  'https://www.mindef.gob.bo/node/484/',
#  'https://www.impuestos.gob.bo/page/566/',
#  'https://egpp.gob.bo/certificacion-2/',
#  'https://www.senasir.gob.bo/assets/contenido/1751/FORM.UNI.2025.10.pdf',
#  'https://www.autoridadminera.gob.bo/index.php/2019/04/24/adecuacion-2/',
#  'https://www.seprec.gob.bo/index.php/tramite51/',
#  'https://www.seprec.gob.bo/index.php/tramite35/',
#  'https://www.seprec.gob.bo/index.php/tramite36/',
#  'https://siretur.produccion.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite57/',
#  'https://www.contraloria.gob.bo/servicios/solvencia-fiscal/',
#  'https://servicios2.sinacom.gob.bo/',
#  'https://tramites.umss.edu.bo/',
#  'https://fnse.gob.bo/index.php/programas-y-proyectos/centro-de-educacion-especial/',
#  'https://lapaz.bo/permiso-de-construccion-remodelacion-y-ampliacion-de-mausoleos-familiares-o-institucionales/',
#  'https://siga.upre.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite60/',
#  'https://ciudadaniadigital.bo/home/',
#  'https://www.sacaba.gob.bo/images/wsacaba/pdf/tramites/economicas/2020/FORMULARIO%20DE%20DECLARACION%20JURADA.pdf',
#  'https://lapaz.bo/baja-tributaria-vehiculos-automotores-terrestres/',
#  'https://mnhn.gob.bo/contacto/',
#  'https://www.gob.bo/tramites/homologacion-de-equipos-de-telecomunicaciones/',
#  'https://lapaz.bo/reemplaque-de-vehiculos-automotores-terrestres/',
#  'https://www.ssutarija.org.bo/salud/afiliaciones/',
#  'https://asfidigital.asfi.gob.bo/inicio/',
#  'https://lapaz.bo/empadronamiento-del-objeto-bienes-inmuebles/',
#  'https://lapaz.bo/solicitud-de-evaluacion-para-instalacion-de-sistema-semaforico-duplicate-1/',
#  'https://lapaz.bo/registro-exenciones-de-instituciones-publicas-del-estado-misiones-diplomaticas-y-consulares-e-instituciones-religiosas/',
#  'https://asfidigital.asfi.gob.bo/cuentasClausuradas/',
#  'https://lapaz.bo/registro-de-transferencias-onerosas-de-bienes-inmuebles/',
#  'https://lapaz.bo/evaluacion-de-estudio-de-impacto-vial/',
#  'https://lapaz.bo/servicio-de-necropsias/',
#  'https://lapaz.bo/emision-de-resolucion-administrativa-de-exencion-de-actividades-economicas/',
#  'https://lapaz.bo/inscripcion-del-vehiculo-automotor-terrestre-por-importacion-directa-con-transferencia-duplicate-1/',
#  'https://lapaz.bo/reemplaque-de-vehiculos-automotores-terrestres-con-transferencia-duplicate-1/',
#  'https://lapaz.bo/inscripcion-de-vehiculo-automotor-terrestre-diplomatico-con-transferencia-por-venta-duplicate-1/',
#  'https://lapaz.bo/registro-de-impuesto-municipal-a-las-transferencias-especiales-de-vehiculos-automotores-terrestres/',
#  'https://www.gob.bo/tramites/solicitud-de-licencia-unica-cooperativas/',
#  'https://firmadigital.bo/herramientas/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/jacobitus/instalacion-de-la-aplicacion-jacobitus-de-escritorio-windows/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/jacobitus/instalacion-de-la-aplicacion-jacobitus-de-escritorio-linux-debian/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/jacobitus/instalacion-de-la-aplicacion-jacobitus-de-escritorio-macos/',
#  'https://solicitud.firmadigital.bo/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/creacion-de-cuenta-de-usuario/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/solicitud-de-dispositivo-criptografico/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/solicitud-de-certificado-natural/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/generacion-de-csr-token/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/registro-de-pago/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/importacion-de-certificado/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/solicitud-de-certificado-juridica/',
#  'https://www.contraloria.gob.bo/',
#  'https://www.elapas.com.bo/',
#  'https://www.sepdep.gob.bo/',
#  'https://www.planificacion.gob.bo/',
#  'https://emavsucre.bo/',
#  'https://www.mhe.gob.bo/',
#  'https://www.ddepotosi.gob.bo/',
#  'https://www.cns.gob.bo/',
#  'https://www.yacana.gob.bo/',
#  'https://www.mintrabajo.gob.bo/',
#  'https://www.dgac.gob.bo/',
#  'https://www.papelbol.com.bo/',
#  'https://lonabol.gob.bo/',
#  'https://senamhi.gob.bo/',
#  'https://www.ait.gob.bo/',
#  'https://www.minculturas.gob.bo/',
#  'https://www.minedu.gob.bo/',
#  'https://ssuoruro.gob.bo/',
#  'https://www.aetn.gob.bo/',
#  'https://www.ebc.gob.bo/',
#  'https://www.mingobierno.gob.bo/',
#  'https://siarh.gob.bo/senari/mapa-del-sitio/',
#  'https://defensoria.gob.bo/',
#  'https://ipelc.gob.bo/',
#  'https://siscert.ipelc.gob.bo/',
#  'https://www.ribb.gob.bo/',
#  'https://www.senapi.gob.bo/',
#  'https://ens.minsalud.gob.bo/aula/',
#  'https://www.inso.gob.bo/',
#  'https://www.semena.gob.bo/',
#  'https://www.anh.gob.bo/',
#  'https://magistratura.organojudicial.gob.bo/',
#  'https://www.geressacaba.com.bo/',
#  'https://sacaba.gob.bo/',
#  'https://www.inlasa.gob.bo/',
#  'https://www.zofracobija.gob.bo/',
#  'https://emapa.gob.bo/',
#  'https://www.sgmbolivia.gob.bo/',
#  'https://rpa.justicia.gob.bo/',
#  'https://tribunaletica.justicia.gob.bo/#/',
#  'https://televias.viasbolivia.gob.bo/auth/login/',
#  'https://www.seprec.gob.bo/index.php/tramite38/',
#  'https://uabjb.edu.bo/index.php/tramites-uab/',
#  'https://www.seprec.gob.bo/index.php/tramite48/',
#  'https://www.seprec.gob.bo/index.php/tramite39/',
#  'https://www.senasir.gob.bo/assets/contenido/1735/FORM.UNI.2025.05.pdf',
#  'https://personalidadesjuridicas.gobernaciondecochabamba.bo/',
#  'https://www.impuestos.gob.bo/page/567/',
#  'https://servicios.senarecom.gob.bo/nim/formM01.php?op=N',
#  'https://www.dgac.gob.bo/autorizaciones-de-vuelos/',
#  'https://sistemasweb.dgac.gob.bo/SISTEMA_SIPCAO/SOLICITUD/Registro_Solicitud_Externo.aspx',
#  'https://www.aj.gob.bo/uploads/docs/doc_20230131_165144.pdf',
#  'https://pajel.aj.gob.bo/Formulario/FormularioSolicitudCredenciales/',
#  'https://lapaz.bo/cremacion-de-cuerpo-fresco-inhumado/',
#  'https://www.seprec.gob.bo/index.php/tramite21/',
#  'https://gestortsj.organojudicial.gob.bo/',
#  'https://www.senapi.gob.bo/propiedad-intelectual/propiedad-industrial/patentes/',
#  'https://eje.gob.bo/',
#  'https://ovt.mintrabajo.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite27/',
#  'https://www.gestora.bo/rentadignidad/guiatramites/',
#  'https://www.seprec.gob.bo/index.php/tramite34/',
#  'https://www.seprec.gob.bo/index.php/tramite28/',
#  'https://www.seprec.gob.bo/index.php/tramite25/',
#  'https://www.asfi.gob.bo/',
#  'https://senamhi.gob.bo/index.php/sysparametros/',
#  'https://pajel.aj.gob.bo/Login/',
#  'https://agenda.impuestos.gob.bo/index.php/login/',
#  'https://www.impuestos.gob.bo/ckeditor/plugins/imageuploader/uploads/78088c6350.pdf',
#  'https://estudiantes.eje.gob.bo/',
#  'https://www.mindef.gob.bo/node/482/',
#  'https://www.senasir.gob.bo/assets/contenido/1731/FORM.UNI.2025.02.pdf',
#  'https://www.senasir.gob.bo/assets/contenido/1730/FORM.UNI.2025.01.pdf',
#  'https://www.mindef.gob.bo/node/487/',
#  'https://www.seprec.gob.bo/index.php/tramite46/',
#  'https://www.senasir.gob.bo/assets/contenido/1740/FORM.UNI.2025.09.pdf',
#  'https://lapaz.bo/cambio-de-radicatoria/',
#  'https://lapaz.bo/requisitos-especificos-para-la-entrega-de-valores-vehiculos/',
#  'https://www.seprec.gob.bo/index.php/tramite52/',
#  'https://lapaz.bo/legalizacion-de-documentacion-copia-legalizada/',
#  'https://www.aps.gob.bo/index.php/proteccion-al-ciudadano/consultas-y-reclamos/',
#  'https://www.senasir.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite54/',
#  'https://www.seprec.gob.bo/index.php/tramite56/',
#  'https://lapaz.bo/actualizacion-de-certificado-de-propiedad-de-vehiculo-automotores-terrestres-duplicate-1/',
#  'https://sac.impuestos.gob.bo/formularios/pdf/TEXTO%20TRAMITES%20EN%20LINEA-AUTO%20MULTADO.pdf',
#  'https://www.impuestos.gob.bo/ckeditor/plugins/imageuploader/uploads/79295e2f9e.pdf',
#  'https://sinacom.gob.bo/',
#  'https://www.gob.bo/tramites/solicitud-de-licencia-para-el-uso-de-frecuencia-para-redes-publicas/',
#  'https://lapaz.bo/duplicado-certificado-de-propiedad-de-vehiculos-automotores-terrestres/',
#  'https://www.seprec.gob.bo/index.php/tramite6/',
#  'https://www.ucpp.gob.bo/cfchm-2/',
#  'https://www.ucpp.gob.bo/formulario-de-solicitud-de-cotizacion-2/',
#  'https://apostilla.rree.gob.bo/#/',
#  'https://tiwanaku.gob.bo/',
#  'https://ait-servicios.ait.gob.bo/doctrina/busqueda/',
#  'https://ait-servicios.ait.gob.bo/registro-publico/',
#  'https://lapaz.bo/autorizaciones-menores/',
#  'https://lapaz.bo/bases-imponibles-registro-valor-tablas/',
#  'https://www.impuestos.gob.bo/page/569/',
#  'https://siatinfo.impuestos.gob.bo/index.php/generalidades-rnc/',
#  'https://lapaz.bo/modificacion-de-datos-tecnicos-del-objeto-gravado-bienes-inmuebles/',
#  'https://lapaz.bo/emision-de-certificaciones/',
#  'https://lapaz.bo/identificacion-y-planificacion-de-senalizacion-o-semaforizacion-vial/',
#  'https://lapaz.bo/inscripcion-de-vehiculo-automotor-terrestre-diplomatico-con-transferencia-por-donacion/',
#  'https://lapaz.bo/inscripcion-vehiculo-automotor-terrestre-por-importacion-de-casa-comercial/',
#  'https://lapaz.bo/aprobacion-de-planos-as-built/',
#  'https://lapaz.bo/informes-tecnicos-de-antecedentes-catastrales/',
#  'https://www.gob.bo/tramites/registro-de-fabricantes-distribuidores-importadores-comercializadores-operadores-y-proveedores-de-servicios-de-telecomunicaciones/',
#  'https://www.misicuni.gob.bo/',
#  'https://www.senasag.gob.bo/',
#  'https://www.afcoop.gob.bo/',
#  'https://egpp.gob.bo/',
#  'https://www.cies.org.bo/',
#  'https://www.inra.gob.bo/',
#  'https://www.umss.edu.bo/',
#  'https://justicia.gob.bo/',
#  'https://sra.justicia.gob.bo/',
#  'https://www.ypfb.gob.bo/',
#  'https://adsib.gob.bo/',
#  'https://firmadigital.bo/herramientas/jacobitus-escritorio/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/solicitud-de-certificado-facturacion-natural/',
#  'https://firmadigital.bo/soporte-tecnico/tutoriales/certificacion-digital/generacion-de-csr-softoken/',
#  'https://www.att.gob.bo/',
#  'https://www.ddepando.edu.bo/',
#  'https://sisep.minedu.gob.bo/',
#  'https://senavex.gob.bo/',
#  'https://www.aps.gob.bo/',
#  'https://www.cps.org.bo/',
#  'https://gamo.gob.bo/',
#  'https://www.cclp.gob.bo/',
#  'https://www.seprec.gob.bo/',
#  'https://www.agetic.gob.bo/',
#  'https://interoperabilidad.agetic.gob.bo/',
#  'https://interoperabilidad.agetic.gob.bo/adm-usuario-fe/#/usuarios',
#  'https://intranet.agetic.gob.bo/nube/s/927iDbpAXEjTidx/download/',
#  'https://fnse.gob.bo/',
#  'https://correos.gob.bo/',
#  'https://www.eba.com.bo/',
#  'https://www.ibc.gob.bo/',
#  'https://otnpb.gob.bo/',
#  'https://www.impuestos.gob.bo/',
#  'https://siat.impuestos.gob.bo/v2/launcher/',
#  'https://siat.impuestos.gob.bo/rnc/public/',
#  'https://lapaz.bo/',
#  'https://www.ruat.gob.bo/',
#  'https://www.mindef.gob.bo/',
#  'https://madretierra.gob.bo/',
#  'https://comibol.gob.bo/',
#  'https://www.emas.com.bo/',
#  'https://www.tarija.bo/',
#  'https://cancilleria.gob.bo/',
#  'https://searpi.org.bo/',
#  'https://www.viasbolivia.gob.bo/',
#  'https://www.inra.gob.bo/certificado-catastral/',
#  'https://inra.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite12/',
#  'https://www.seprec.gob.bo/index.php/tramite40/',
#  'https://buzon.organojudicial.gob.bo/',
#  'https://www.fndr.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite17/',
#  'https://lapaz.bo/evaluacion-tecnica-para-regularizacion-de-trazos-viales/',
#  'https://www.senasir.gob.bo/assets/contenido/1736/FORM.UNI.2025.06.pdf',
#  'https://www.ribb.gob.bo/web/site/refinfo/',
#  'https://www.seprec.gob.bo/index.php/tramite50/',
#  'https://lapaz.bo/reemplaque-de-vehiculos-automotores-terrestres-con-transferencia-diplomatico-duplicate-1/',
#  'https://www.mindef.gob.bo/node/488/',
#  'https://oficinavirtual.gestora.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite13/',
#  'https://www.seprec.gob.bo/index.php/tramite10/',
#  'https://lapaz.bo/division-y-particion-de-predios/',
#  'https://www.seprec.gob.bo/index.php/tramite18/',
#  'https://certcpv2024.ine.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite45/',
#  'https://www.senasir.gob.bo/assets/contenido/1739/FORM.UNI.2025.08.pdf',
#  'https://ucas.economiayfinanzas.gob.bo/casweb/crequisitos/',
#  'https://cancilleria.gob.bo/transparencia/anfora/formulario/',
#  'https://www.seprec.gob.bo/index.php/tramite33/',
#  'https://www.seprec.gob.bo/index.php/tramite30/',
#  'https://minedu.legas.gob.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite53/',
#  'https://firmadigital.bo/servicios/certificacion-digital/',
#  'https://www.seprec.gob.bo/index.php/tramite7/',
#  'https://www.seprec.gob.bo/index.php/tramite58/',
#  'https://lapaz.bo/registro-del-impuesto-a-la-transferencias-de-vehiculos-automotores-terrestres-por-adjudicacion-judicial-duplicate-1/',
#  'https://servicios.senarecom.gob.bo/nim/formNiar.php',
#  'https://lapaz.bo/duplicado-de-placa-y-plaqueta/',
#  'https://aaps.gob.bo/index.php?option=com_content&view=article&id=108&Itemid=304',
#  'https://lapaz.bo/traslado-de-restos-a-sepultura-perpetua/',
#  'https://lapaz.bo/bases-imponibles-registro-valor-libros/',
#  'https://lapaz.bo/emision-de-liquidaciones-con-el-beneficio-del-descuento-por-la-variable-de-identificacion-de-actividades-economicas/',
#  'https://lapaz.bo/planificacion-del-reordenamiento-vial/',
#  'https://lapaz.bo/registro-de-transferencias-onerosas-de-bienes-inmuebles-por-adjudicacion-judicial/',
#  'https://www.gob.bo/tramites/solicitud-de-licencia-para-el-uso-de-frecuencia-para-redes-privadas-y-radioenlaces/',
#  'https://lapaz.bo/registro-de-rescision-o-desistimiento-del-impuesto-municipal-a-la-transferencia-onerosa-de-vehiculos-automotores-terrestres-2/',
#  'https://www.gob.bo/tramites/solicitud-de-licencia-unica-empresas-privadas/',
#  'https://www.impuestos.gob.bo/ckeditor/plugins/imageuploader/uploads/2610c9ea8.pdf',
#  'https://www.impuestos.gob.bo/page/529/',
#  'https://lapaz.bo/fraccionamientos-en-propiedad-horizontal/',
#  'https://lapaz.bo/regularizacion-o-actualizacion-de-propiedad/',
#  'https://lapaz.bo/inscripcion-vehiculo-automotor-terrestre-por-importacion-de-casa-comercial-con-transferencia-duplicate-1/',
#  'https://www.gob.bo/tramites/solicitud-de-habilitacion-especifica/',
#  'https://lapaz.bo/inscripcion-de-vehiculo-automotor-terrestre-casa-comercial-maquinaria-pesada-duplicate-1/',
#  'https://lapaz.bo/registro-de-impuesto-municipal-a-las-transferencias-onerosas-de-vehiculos-automotores-terrestres/',
#  'https://www.gob.bo/tramites/solicitud-de-licencia-unica-entidades-publicas/',
#  'https://www.eje.gob.bo/',
#  'https://aben.gob.bo/',
#  'https://gobernaciondecochabamba.bo/web/inicio/',
#  'https://www.procuraduria.gob.bo/',
#  'https://www.ddebeni.edu.bo/',
#  'https://www.gacetaoficialdebolivia.gob.bo/',
#  'https://www.gacetaoficialdebolivia.gob.bo/app/webroot/archivos/modelo_solicitud.docx',
#  'https://www.gacetaoficialdebolivia.gob.bo/app/webroot/archivos/FORMULARIO_2021.pdf',
#  'https://emagua.gob.bo/',
#  'https://utupakkatari.edu.bo/',
#  'https://www.ruralytierras.gob.bo/',
#  'https://www.ssubeni.org.bo/',
#  'https://www.policia.bo/',
#  'https://fofim.gob.bo/',
#  'https://www.aaps.gob.bo/',
#  'https://www.sergeomin.gob.bo/',
#  'https://www.senape.gob.bo/',
#  'https://www.boa.bo/',
#  'https://www.cochabamba.bo/',
#  'https://www.economiayfinanzas.gob.bo/',
#  'https://www.aj.gob.bo/',
#  'https://editorialestado.bo/',
#  'https://www.muserpol.gob.bo/',
#  'https://tsj.bo/',
#  'https://cartonbol.com.bo/',
#  'https://emi.edu.bo/',
#  'https://insa.gob.bo/',
#  'https://www.tribunalagroambiental.bo/',
#  'https://snabol.com.bo/',
#  'https://www.ine.gob.bo/',
#  'https://www.minsalud.gob.bo/',
#  'https://senasba.gob.bo/',
#  'https://www.uatf.edu.bo/',
#  'https://direcciondepartamentaldeeducacionoruro.gob.bo/',
#  'https://ebid.edu.bo/',
#  'https://www.gamvm.gob.bo/',
#  'https://samapa.gob.bo/',
#  'https://sepdavi.gob.bo/',
#  'https://developer.ciudadaniadigital.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite19/',
#  'https://www.seprec.gob.bo/index.php/tramite20/',
#  'https://www.seprec.gob.bo/index.php/tramite47/',
#  'https://consulta.setar.com.bo/Ley1886Tar/servlet/login/',
#  'https://lapaz.bo/traslados-cuerpo-mayor-a-cuerpo-menor/',
#  'https://www.mindef.gob.bo/node/489/',
#  'https://www.seprec.gob.bo/index.php/tramite4/',
#  'https://www.seprec.gob.bo/index.php/tramite23/',
#  'https://www.seprec.gob.bo/index.php/tramite59/',
#  'https://www.seprec.gob.bo/index.php/tramite1/',
#  'https://fnse.gob.bo/index.php/programas-y-proyectos/proyectos-productivos/',
#  'https://cronos.ypfb.gob.bo/',
#  'https://sucre.bo/wp-content/uploads/2025/03/Formulario-permiso-de-viaje.pdf',
#  'https://www.seprec.gob.bo/index.php/tramite24/',
#  'https://www.seprec.gob.bo/index.php/tramite26/',
#  'https://lapaz.bo/cremacion-de-cuerpo-fresco-sin-inhumar/',
#  'https://www.seprec.gob.bo/index.php/tramite14/',
#  'https://fnse.gob.bo/index.php/programas-y-proyectos/pronassle/',
#  'https://seta.gobernaciondecochabamba.bo/',
#  'https://www.seprec.gob.bo/index.php/tramite2/',
#  'https://www.seprec.gob.bo/index.php/tramite31/',
#  'https://www.senapi.gob.bo/propiedad-intelectual/propiedad-industrial/signos-distintivos/',
#  'https://www.seprec.gob.bo/index.php/tramite22/',
#  'https://lapaz.bo/internacion-de-restos-para-cremacion-servicio-suspendido-temporalmente/',
#  'https://lapaz.bo/cambio-de-radicatoria-con-transferencia-duplicate-1-2/',
#  'https://lapaz.bo/planificacion-del-sistema-de-movilidad-duplicate-1/',
#  'https://www.seprec.gob.bo/index.php/tramite43/',
#  'https://www.ssuoruro.gob.bo/afiliacion/',
#  'https://fnse.gob.bo/index.php/programas-y-proyectos/viviendas/',
#  'https://egpp.gob.bo/oferta-academica/',
#  'https://lapaz.bo/modificacion-de-datos-tecnicos-generales/',
#  'https://www.seprec.gob.bo/index.php/tramite55/',
#  'https://lapaz.bo/autorizacion-de-salida-de-restos-a-otro-cementerio/',
#  'https://www.gob.bo/tramites/autorizacion-previa-de-importacion-y-o-certificacion-para-despacho-aduanero-para-equipos-transmisores-de-radiofusion-aparatos-y-dispositivos-para-recepcion-de-television-satelital-decodificadores-dongles-y-para-aparatos-de-radar-radionavegacion-y-radiotelemando-excepto-receptores-gps/',
#  'https://lapaz.bo/inscripcion-del-vehiculo-automotor-terrestre-importacion-directa-con-transferencia-duplicate-1/',
#  'https://lapaz.bo/aprobacion-de-planos-as-built-en-infraestructuras-de-preservacion-patrimonial/',
#  'https://lapaz.bo/certificado-de-obito/',
#  'https://www.impuestos.gob.bo/page/382/',
#  'https://lapaz.bo/duplicado-de-certificado-de-propiedad-con-transferencia-onerosa-duplicate-1/',
#  'https://lapaz.bo/certificaciones/',
#  'https://lapaz.bo/emision-de-liquidaciones-con-el-beneficio-de-exencion-del-50-a-instituciones-educativas/',
#  'https://lapaz.bo/modificaciones-de-datos-del-contribuyente-en-el-padron-municipal-de-contribuyentes/',
#  'https://lapaz.bo/registro-de-rescision-o-desistimiento-del-impuesto-municipal-a-la-transferencia-impuesto-municipal-a-la-transferencia-onerosa/',
#  'https://lapaz.bo/verificaciones-tecnicas-inmuebles/',
#  'https://lapaz.bo/emision-de-proforma-impuesto-municipal-a-la-propiedad-de-vehiculos-automotores-terrestres/',
#  'https://www.gob.bo/tramites/inscripcion-en-el-registro-de-fabricantes-proveedores-y-comercializadores-de-equipos-de-telecomunicaciones-y-tic/',
#  'https://lapaz.bo/empadronamiento-contribuyentes/',
#  'https://lapaz.bo/inscripcion-del-vehiculo-automotor-terrestre-por-importacion-directa-duplicate-1/',
#  'https://lapaz.bo/inscripcion-vehiculo-automotor-terrestre-por-importacion-de-casa-comercial-duplicate-1/',
#  'https://www.gob.bo/tramites/autorizacion-previa-de-importacion-y-o-certificacion-para-despacho-aduanero-para-equipos-con-fines-cientificos-academicos-o-casos-de-internacion-temporal/',
#  'https://lapaz.bo/inscripcion-vehiculo-automotor-terrestre-por-importacion-de-casa-comercial-con-transferencia-duplicate-1-2/',
#  'https://lapaz.bo/registro-de-impuesto-municipal-a-las-transferencias-onerosas-de-vehiculos-automotores-terrestres-duplicate-1/',
#  'https://www.dab.gob.bo/',
#  'https://www.fps.gob.bo/',
#  'https://uabjb.edu.bo/',
#  'https://www.setar.com.bo/',
#  'https://www.sernap.gob.bo/',
#  'https://www.bcb.gob.bo/',
#  'https://www.fundacionculturalbcb.gob.bo/index.php',
#  'https://www.uto.edu.bo/',
#  'https://covipol.gob.bo/',
#  'https://dirnoplu.gob.bo/',
#  'https://www.fonabosque.gob.bo/',
#  'https://www.ucpp.gob.bo/',
#  'https://www.autoridadminera.gob.bo/',
#  'https://www.fondesif.gob.bo/',
#  'https://produccion.gob.bo/',
#  'https://www.upre.gob.bo/',
#  'https://www.asuss.gob.bo/',
#  'https://www.eecgnv.gob.bo/',
#  'https://www.senarecom.gob.bo/',
#  'https://www.umsa.bo/',
#  'https://santacruz-dde.edu.bo/',
#  'https://mnhn.gob.bo/',
#  'https://www.ssutarija.org.bo/',
#  'https://www.agemed.gob.bo/',
#  'https://fonadin.gob.bo/',
#  'https://www.selaoruro.gob.bo/',
#  'https://www.asfi.gob.bo/index.html',
#  'https://www.ylb.gob.bo/',
#  'https://sucre.bo/',
#  'https://www.segip.gob.bo/',
#  'https://www.probolivia.gob.bo/',
#  'https://www.sepmud.gob.bo/']

# %%
len(sitios)
# Out:
# 433

# %%
import gzip
from warcio.archiveiterator import ArchiveIterator

def extract_json_xhr_calls(warc_file):
    json_xhr_calls = []

    open_func = gzip.open if warc_file.endswith(".gz") else open
    with open_func(warc_file, "rb") as stream:
        for record in ArchiveIterator(stream):
            if record.rec_type == "response":
                url = record.rec_headers.get_header("WARC-Target-URI")
                content_type = record.rec_headers.get_header("Content-Type")

                if content_type : #and ("application/json" in content_type or "application/x-xhr-json" in content_type):
                    json_xhr_calls.append((url,content_type))

    return json_xhr_calls

# %%
import os

warc_dir = "/content/www_gob_bo_-20250824_015305/archive"
all_json_xhr_calls = []

# Iterate through files in the specified directory
for root, _, files in os.walk(warc_dir):
    for file in files:
        if file.endswith(".warc.gz"):
            warc_file = os.path.join(root, file)
            print(f"Processing JSON/XHR calls from: {warc_file}")
            json_xhr_calls = extract_json_xhr_calls(warc_file)
            all_json_xhr_calls.extend(json_xhr_calls)

print(f"Total JSON/XHR calls extracted: {len(all_json_xhr_calls)}")
# Out:
# Processing JSON/XHR calls from: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311432-3.warc.gz
# Processing JSON/XHR calls from: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311616-1.warc.gz
# Processing JSON/XHR calls from: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311411-0.warc.gz
# Processing JSON/XHR calls from: /content/www_gob_bo_-20250824_015305/archive/rec-bc4a53349c14-www_gob_bo_-20250824_015305-20250824015311464-2.warc.gz
# Total JSON/XHR calls extracted: 18193
# Extracted JSON/XHR Calls:
# ('https://www.gob.bo/eventos-de-vida', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/css/28e3b03a6887665e.css', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/css/22777d5f94aecdf1.css', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/css/d645a791e5bd11f8.css', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/main-app-fe8d7f0c1caeac6a.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/3719-6c5b1cd8100b9022.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/7058-630083b694e07a4f.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/1064-fb05851fc72f8814.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/529-92d028d510d3b7b2.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/4425-eb9b9d97ab122d1d.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/6648-49089e00e6a8b60d.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/8834-4ac3ca6f14df2f15.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/4723-67b24db82128baf4.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/5223-0f8a27dcbc5d7552.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/9606-6245d739c46583f8.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/7138-37bb25079c6bf32d.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/1137-90cc2fb73bf4d2fc.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/app/(publico)/layout-170beb2b159acba2.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/7245-868ca78a3dc5044d.js', 'application/http; msgtype=response')
# ('https://www.gob.bo/_next/static/chunks/3155-7362ca8617ee7662.js', 'application/http; msgtype=response')

# %%
df_2 = pd.DataFrame(all_json_xhr_calls)

# %%
df_2
# Out:
#                                                        0  \
# 0                     https://www.gob.bo/eventos-de-vida
# 1      https://www.gob.bo/_next/static/css/28e3b03a68...
# 2      https://www.gob.bo/_next/static/css/22777d5f94...
# 3      https://www.gob.bo/_next/static/css/d645a791e5...
# 4      https://www.gob.bo/_next/static/chunks/main-ap...
# ...                                                  ...
# 18188  https://www.gob.bo/entidades/gobierno-autonomo...
# 18189  https://www.gob.bo/categorias/impuestos?_rsc=f...
# 18190  https://www.gob.bo/categorias/empresas?_rsc=f74k1
# 18191                https://www.gob.bo/about?_rsc=f74k1
# 18192  https://www.gob.bo/preguntas-frecuentes?_rsc=f...
#
#                                         1
# 0      application/http; msgtype=response
# 1      application/http; msgtype=response
# 2      application/http; msgtype=response
# 3      application/http; msgtype=response
# 4      application/http; msgtype=response
# ...                                   ...
# 18188  application/http; msgtype=response
# 18189  application/http; msgtype=response
# 18190  application/http; msgtype=response
# 18191  application/http; msgtype=response
# 18192  application/http; msgtype=response
#
# [18193 rows x 2 columns]
